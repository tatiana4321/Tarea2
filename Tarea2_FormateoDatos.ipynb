# %%
import pandas as pd

linkToFile='https://docs.google.com/spreadsheets/d/e/2PACX-1vSPVJIoDhupNyUpYD65FSHt6kMmF_KaxE2RD6CV1FOMP4vVw7WfKQMqpqo0ieD9vhMAmYP1NpBmw0od/pub?gid=658985149&single=true&output=csv'
dataUN=pd.read_csv(linkToFile)

dataUN

# %%
dataUN.info()

# %%
dataUN_new=dataUN.copy()

# %% [markdown]
# ##Columns

# %%
# Deleting unnecesary columns

#empty_columns = dataUN.columns[dataUN.isna().all(axis=0)]
#dataUN_new.drop(columns=empty_columns, inplace=True)

toDrop = ['Back', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 11', 'Unnamed: 13']
dataUN_new.drop(columns=toDrop, inplace=True)

dataUN_new
# Out:
#     Table 1. Human Development Index and its components  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                              Country
# ..                                                 ...
# 271                          Column 2: UNDESA (2022a).
# 272  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275  Column 6: Calculated based on data in columns ...
#
#                         Unnamed: 2                Unnamed: 4  \
# 0                              NaN                       NaN
# 1                              NaN                      SDG3
# 2                              NaN                       NaN
# ...

# %%
# Fixing column names

new_columns=dataUN_new.iloc[3]+" "+dataUN_new.iloc[5]
dataUN_new.columns=new_columns

dataUN_new.columns.values[0] = 'Country'

dataUN_new
# Out:
#                                                Country  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                              Country
# ..                                                 ...
# 271                          Column 2: UNDESA (2022a).
# 272  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI) 2021 Life expectancy at birth 2021  \
# 0                                  NaN                           NaN
# 1                                  NaN                          SDG3
# 2                                  NaN                           NaN
# ...

# %%
dataUN_new.columns.to_list()
# Out:
# ['Country',
#  'Human Development Index (HDI) 2021',
#  'Life expectancy at birth 2021',
#  'Expected years of schooling 2021',
#  'Mean years of schooling 2021',
#  'Gross national income (GNI) per capita 2021',
#  'GNI per capita rank minus HDI rank 2021',
#  'HDI rank 2020']

# %%
dataUN_new.columns=dataUN_new.columns.str.strip()
dataUN_new.columns=dataUN_new.columns.str.replace(r"\s","_",regex=True).str.replace(r"\W","",regex=True)

dataUN_new.columns.to_list()
# Out:
# ['Country',
#  'Human_Development_Index_HDI_2021',
#  'Life_expectancy_at_birth_2021',
#  'Expected_years_of_schooling_2021',
#  'Mean_years_of_schooling_2021',
#  'Gross_national_income_GNI_per_capita_2021',
#  'GNI_per_capita_rank_minus_HDI_rank_2021',
#  'HDI_rank_2020']

# %%
cat=dataUN_new[pd.isnull(dataUN_new.Human_Development_Index_HDI_2021)]

cat.head(18)
# Out:
#                             Country Human_Development_Index_HDI_2021  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 6       VERY HIGH HUMAN DEVELOPMENT                              NaN
# 73           HIGH HUMAN DEVELOPMENT                              NaN
# 123        MEDIUM HUMAN DEVELOPMENT                              NaN
# 168           LOW HUMAN DEVELOPMENT                              NaN
# 201  OTHER COUNTRIES OR TERRITORIES                              NaN
# 206                             NaN                              NaN
# 207        Human development groups                              NaN
# 212                             NaN                              NaN
# 214                             NaN                              NaN
# 215                         Regions                              NaN
# ...

# %%
dataUN_new.loc[7:72,'Human_Dev']=cat.Country[6]
dataUN_new.loc[74:122,'Human_Dev']=cat.Country[73]
dataUN_new.loc[124:167,'Human_Dev']=cat.Country[123]
dataUN_new.loc[169:200,'Human_Dev']=cat.Country[168]
dataUN_new.loc[202:206,'Human_Dev']=cat.Country[201]
dataUN_new.loc[208:214,'Human_Dev']=cat.Country[207]
dataUN_new.loc[216:229,'Human_Dev']=cat.Country[215]

mapper1={cat.Country[6]:1,cat.Country[73]:2,cat.Country[123]:3,cat.Country[168]:4,cat.Country[201]:5.1,cat.Country[207]:5.2,cat.Country[215]:5.3}
dataUN_new.Human_Dev.replace(mapper1,inplace=True)

# %%
dataUN_new.head(10)
# Out:
#                        Country Human_Development_Index_HDI_2021  \
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3                          NaN    Human Development Index (HDI)
# 4                      Country                            Value
# 5                          NaN                             2021
# 6  VERY HIGH HUMAN DEVELOPMENT                              NaN
# 7                  Switzerland                              962
# 8                       Norway                              961
# 9                      Iceland                              959
#
#   Life_expectancy_at_birth_2021 Expected_years_of_schooling_2021  \
# 0                           NaN                              NaN
# 1                          SDG3                           SDG4.3
# ...

# %% [markdown]
# ##Filas

# %%
# Deleting unnecesary rows
dataUN_new.drop(range(7), inplace=True)

# Reseting the indexes
dataUN_new=dataUN_new.reset_index(drop=True)

dataUN_new

# %%
#Checking the indexes with NaN in the column 'Life_expectancy_at_birth_2021?

dataUN_new[pd.isnull(dataUN_new.Life_expectancy_at_birth_2021)].index
dataUN_new.drop(dataUN_new[pd.isnull(dataUN_new.Life_expectancy_at_birth_2021)].index,inplace=True)

dataUN_new=dataUN_new.reset_index(drop=True)

dataUN_new
# Out:
#                                                Country  \
# 0                                          Switzerland
# 1                                               Norway
# 2                                              Iceland
# 3                               Hong Kong, China (SAR)
# 4                                            Australia
# ..                                                 ...
# 205                                 Sub-Saharan Africa
# 206                          Least developed countries
# 207                     Small island developing states
# 208  Organisation for Economic Co-operation and Dev...
# 209                                              World
#
#     Human_Development_Index_HDI_2021 Life_expectancy_at_birth_2021  \
# 0                                962                          84.0
# 1                                961                          83.2
# 2                                959                          82.7
# ...

# %%
dataUN_2=dataUN_new.copy()

# complete data
#dataUN_2=dataUN_2[~dataUN_2.isna().any(axis=1)].reset_index(drop=True)

dataUN_2

# %%
#Datos

def noSpaces(x,errors='coerce'):
  x=x.str.strip()
  return x

dataUN_new.iloc[:,range(0,8)]=dataUN_new.iloc[:,range(0,8)].apply(noSpaces)

# %%
#Símbolos

a=set(dataUN_new.Human_Development_Index_HDI_2021.str.extractall('(\W)').loc[:,0].to_list())-set('.')
b=set(dataUN_new.Life_expectancy_at_birth_2021.str.extractall('(\W)').loc[:,0].to_list())-set('.')
c=set(dataUN_new.Expected_years_of_schooling_2021.str.extractall('(\W)').loc[:,0].to_list())-set('.')
d=set(dataUN_new.Mean_years_of_schooling_2021.str.extractall('(\W)').loc[:,0].to_list())-set('.')
e=set(dataUN_new.Gross_national_income_GNI_per_capita_2021.str.extractall('(\W)').loc[:,0].to_list())-set('.')
f=set(dataUN_new.GNI_per_capita_rank_minus_HDI_rank_2021.str.extractall('(\W)').loc[:,0].to_list())-set('.')
g=set(dataUN_new.HDI_rank_2020.str.extractall('(\W)').loc[:,0].to_list())-set('.')
a,b,c,d,e,f,g
# Out:
# (set(), set(), set(), set(), {','}, {'-', '—'}, {'—'})

# %%
dataUN_new.Gross_national_income_GNI_per_capita_2021=dataUN_new.Gross_national_income_GNI_per_capita_2021.str.replace(',','')
dataUN_new.GNI_per_capita_rank_minus_HDI_rank_2021=dataUN_new.GNI_per_capita_rank_minus_HDI_rank_2021.str.extract(pat=r'(^-\d+$|\d+)')
dataUN_new.HDI_rank_2020=dataUN_new.HDI_rank_2020.str.extract(pat=r'(^\w+)')

# %%
dataUN_new[dataUN_new.Human_Development_Index_HDI_2021.str.contains(pat=r'\W')]
# Out:
#                                  Country Human_Development_Index_HDI_2021  \
# 191  Korea (Democratic People's Rep. of)                               ..
# 192                               Monaco                               ..
# 193                                Nauru                               ..
# 194                              Somalia                               ..
#
#     Life_expectancy_at_birth_2021 Expected_years_of_schooling_2021  \
# 191                          73.3                             10.8
# 192                          85.9                               ..
# 193                          63.6                             11.7
# 194                          55.3                               ..
#
#     Mean_years_of_schooling_2021 Gross_national_income_GNI_per_capita_2021  \
# 191                           ..                                        ..
# 192                           ..                                        ..
# ...

# %%
dataUN_new.Human_Development_Index_HDI_2021=dataUN_new.Human_Development_Index_HDI_2021.str.extract(pat='(\d+)')
dataUN_new.Expected_years_of_schooling_2021=dataUN_new.Expected_years_of_schooling_2021.str.extract(pat='(\d+.\d+)')
dataUN_new.Mean_years_of_schooling_2021=dataUN_new.Mean_years_of_schooling_2021.str.extract(pat='(\d+.\d+)')
dataUN_new.Gross_national_income_GNI_per_capita_2021=dataUN_new.Gross_national_income_GNI_per_capita_2021.str.extract(pat='(\d+)')

# %% [markdown]
# ##A

# %%
dataUN_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 9 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    210 non-null    object
#  1   Human_Development_Index_HDI_2021           206 non-null    object
#  2   Life_expectancy_at_birth_2021              210 non-null    object
#  3   Expected_years_of_schooling_2021           208 non-null    object
#  4   Mean_years_of_schooling_2021               206 non-null    object
#  5   Gross_national_income_GNI_per_capita_2021  208 non-null    object
#  6   GNI_per_capita_rank_minus_HDI_rank_2021    191 non-null    object
#  7   HDI_rank_2020                              191 non-null    object
#  8   Human_Dev                                  210 non-null    float64
# dtypes: float64(1), object(8)
# memory usage: 14.9+ KB

# %%
dataUN_new[dataUN_new.duplicated(subset='Country')]
# Out:
# Empty DataFrame
# Columns: [Country, Human_Development_Index_HDI_2021, Life_expectancy_at_birth_2021, Expected_years_of_schooling_2021, Mean_years_of_schooling_2021, Gross_national_income_GNI_per_capita_2021, GNI_per_capita_rank_minus_HDI_rank_2021, HDI_rank_2020, Human_Dev]
# Index: []

# %%
dataUN_new[dataUN_new.Country.str.contains(r'[^\w\s]')]
# Out:
#                                                Country  \
# 3                               Hong Kong, China (SAR)
# 19                                 Korea (Republic of)
# 75                          Iran (Islamic Republic of)
# 80                               Moldova (Republic of)
# 105                                Palestine, State of
# 117                   Bolivia (Plurinational State of)
# 119                 Venezuela (Bolivarian Republic of)
# 133                   Micronesia (Federated States of)
# 139                   Lao People's Democratic Republic
# 140                                        Timor-Leste
# 143                              Eswatini (Kingdom of)
# 158                                      Côte d'Ivoire
# 159                      Tanzania (United Republic of)
# 176                                      Guinea-Bissau
# 178                 Congo (Democratic Republic of the)
# 191                Korea (Democratic People's Rep. of)
# ...

# %%
dataUN_new[dataUN_new.Country.str.contains(r"\w*[\u00C0-\u01DA']\w*")]
# Out:
#                                  Country Human_Development_Index_HDI_2021  \
# 47                               Türkiye                              838
# 139     Lao People's Democratic Republic                              607
# 158                        Côte d'Ivoire                              550
# 191  Korea (Democratic People's Rep. of)                              NaN
#
#     Life_expectancy_at_birth_2021 Expected_years_of_schooling_2021  \
# 47                           76.0                             18.3
# 139                          68.1                             10.1
# 158                          58.6                             10.7
# 191                          73.3                             10.8
#
#     Mean_years_of_schooling_2021 Gross_national_income_GNI_per_capita_2021  \
# 47                           8.6                                     31033
# 139                          5.4                                      7700
# ...

# %%
pip install unidecode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 5.1 MB/s eta 0:00:00
# ...

# %%
from unidecode import unidecode

dataUN_new['Country']=dataUN_new.Country.apply(unidecode)

# %%
dataUN_new['Country']=dataUN_new.Country.str.upper()

# %%
def symbols(x,errors='ignore'):
  x=x.str.contains(r'\D\.')
  return x

# %%
dataUN_new.head(1)
# Out:
#        Country Human_Development_Index_HDI_2021 Life_expectancy_at_birth_2021  \
# 0  SWITZERLAND                              962                          84.0
#
#   Expected_years_of_schooling_2021 Mean_years_of_schooling_2021  \
# 0                             16.5                         13.9
#
#   Gross_national_income_GNI_per_capita_2021  \
# 0                                     66933
#
#   GNI_per_capita_rank_minus_HDI_rank_2021 HDI_rank_2020  Human_Dev
# 0                                       5             3        1.0

# %%
symbols(dataUN_new.Human_Development_Index_HDI_2021).value_counts()
# Out:
# Human_Development_Index_HDI_2021
# False    206
# Name: count, dtype: int64

# %%
symbols(dataUN_new.Life_expectancy_at_birth_2021).value_counts()
# Out:
# Life_expectancy_at_birth_2021
# False    210
# Name: count, dtype: int64

# %%
symbols(dataUN_new.Expected_years_of_schooling_2021).value_counts()
# Out:
# Expected_years_of_schooling_2021
# False    208
# Name: count, dtype: int64

# %%
symbols(dataUN_new.Mean_years_of_schooling_2021).value_counts()
# Out:
# Mean_years_of_schooling_2021
# False    206
# Name: count, dtype: int64

# %%
symbols(dataUN_new.Gross_national_income_GNI_per_capita_2021).value_counts()
# Out:
# Gross_national_income_GNI_per_capita_2021
# False    208
# Name: count, dtype: int64

# %%
symbols(dataUN_new.GNI_per_capita_rank_minus_HDI_rank_2021).value_counts()
# Out:
# GNI_per_capita_rank_minus_HDI_rank_2021
# False    191
# Name: count, dtype: int64

# %%
symbols(dataUN_new.HDI_rank_2020).value_counts()
# Out:
# HDI_rank_2020
# False    191
# Name: count, dtype: int64

# %%
dataUN_new.Human_Development_Index_HDI_2021 = pd.to_numeric(dataUN_new.Human_Development_Index_HDI_2021,errors='coerce')
dataUN_new.Life_expectancy_at_birth_2021 = pd.to_numeric(dataUN_new.Life_expectancy_at_birth_2021,errors='coerce')
dataUN_new.Expected_years_of_schooling_2021 = pd.to_numeric(dataUN_new.Expected_years_of_schooling_2021,errors='coerce')
dataUN_new.Mean_years_of_schooling_2021 = pd.to_numeric(dataUN_new.Mean_years_of_schooling_2021,errors='coerce')
dataUN_new.Gross_national_income_GNI_per_capita_2021 = pd.to_numeric(dataUN_new.Gross_national_income_GNI_per_capita_2021,errors='coerce')
dataUN_new.GNI_per_capita_rank_minus_HDI_rank_2021 = pd.to_numeric(dataUN_new.GNI_per_capita_rank_minus_HDI_rank_2021,errors='coerce')
dataUN_new.HDI_rank_2020 = pd.to_numeric(dataUN_new.HDI_rank_2020,errors='coerce')

# %%
dataUN_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 9 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    210 non-null    object
#  1   Human_Development_Index_HDI_2021           206 non-null    float64
#  2   Life_expectancy_at_birth_2021              210 non-null    float64
#  3   Expected_years_of_schooling_2021           208 non-null    float64
#  4   Mean_years_of_schooling_2021               206 non-null    float64
#  5   Gross_national_income_GNI_per_capita_2021  208 non-null    float64
#  6   GNI_per_capita_rank_minus_HDI_rank_2021    191 non-null    float64
#  7   HDI_rank_2020                              191 non-null    float64
#  8   Human_Dev                                  210 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 14.9+ KB
